# %%
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
nltk.download('punkt')
# nltk.download('punk_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\AB
# [nltk_data]     TRADERS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text="hello for there; mr dmith id waiting for you ! do you havae the "

# %%
text.split()
# Out:
# ['hello',
#  'for',
#  'there;',
#  'mr',
#  'dmith',
#  'id',
#  'waiting',
#  'for',
#  'you',
#  '!',
#  'do',
#  'you',
#  'havae',
#  'the']

# %%
from nltk.corpus import stopwords
sentence= sent_tokenize(text)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\AB
# [nltk_data]     TRADERS\AppData\Roaming\nltk_data...
# True

# %%
stop_words=set(stopwords.words('english'))
text ="the quik is the brown for jump over the lazy ...."
tokens=word_tokenize(text.lower())

filtered=[]
for t in tokens:
    if t not in stop_words and t.isalpha():
        filtered.append(t)

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\AB
# [nltk_data]     TRADERS\AppData\Roaming\nltk_data...
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\AB
# [nltk_data]     TRADERS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\AB
# [nltk_data]     TRADERS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
lematization= WordNetLemmatizer()
print(lematization.lemmatize("running",pos='v')) 
print(lematization.lemmatize("happyes",pos='v'))
# Out:
# run
# happyes
